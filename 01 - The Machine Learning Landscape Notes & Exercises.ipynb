# %% [markdown]
# # The Machine Learning Landscape Notes

# %% [markdown]
# ## Example 1 - 1. Training and running a linear model using Scikit-Learn

# %% [markdown]
# ### Import relevant libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ### Download and prepare the data

# %%
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# %% [markdown]
# ### Visualize the data

# %%
lifesat.plot(kind='scatter', grid=True, x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# %%
lifesat.head()
# Out:
#    Country  GDP per capita (USD)  Life satisfaction
# 0   Russia          26456.387938                5.8
# 1   Greece          27287.083401                5.4
# 2   Turkey          28384.987785                5.5
# 3   Latvia          29932.493910                5.9
# 4  Hungary          31007.768407                5.6

# %% [markdown]
# ### Select a Linear Model

# %%
# model = LinearRegression()
model = KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# ### Train the Model

# %%
model.fit(X, y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# ### Make a prediction for Cyprus

# %%
X_new = [[37_655.2]] # Cyprus' GDP per capita in 2020
print(model.predict(X_new))
# Out:
# [[6.33333333]]

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1. How would you define machine learning?

# %% [markdown]
# It is the science of programming computers so they can learn from data.

# %% [markdown]
# ### 2. Can you name four types of applications where it shines?

# %% [markdown]
# - Detecting tumors in brain scans
# - Automatically classifying news articles
# - Detecting credit card fraud
# - Summarizing long documents automatically

# %% [markdown]
# ### 3. What is a labeled training set?

# %% [markdown]
# Labeled training set is data you feed to the algorithm that includes desired solutions.

# %% [markdown]
# ### 4. What are the two most common supervised tasks?

# %% [markdown]
# - Classification
# - Regression

# %% [markdown]
# ### 5. Can you name four common unsupervised tasks?

# %% [markdown]
# - Visualization
# - Dimensionality Reduction
# - Anomaly Detection
# - Association Rule Learning

# %% [markdown]
# ### 6. What type of algorithm would you use to allow a robot to walk in various unknown terrains?

# %% [markdown]
# Reinforcement learning algorithm would use to allow a robot to walk in various unknown terrains.
#
# - _Observe_ the environment.
# - _Select_ action using policy (best strategy)
# - Perform _actions_
# - Get _rewards_ or penalty
# - _Update_ policy
# - _Iterate_ until an optimal policy is found

# %% [markdown]
# ### 7. What type of algorithm would you use to segment your customers into multiple groups?

# %% [markdown]
# Hierarchical clustering algorithm will subdivide each group into smaller groups.

# %% [markdown]
# ### 8. Would you frame the problem of spam detection as a supervised learning problem or an unsupervised learning problem?

# %% [markdown]
# I would frame the problem of spam detection as a supervised learning problem because it needs to be trained with many example emails along with their class (spam or ham), and it must learn how to classify new emails.

# %% [markdown]
# ### 9. What is an online learning system?

# %% [markdown]
# When you train the system incrementally by feeding it data instances sequentially, either individually or in small groups (mini-batches).
#
# Benefits:
# - It is useful for systems that _need to adapt to change extremely rapidly_ (e.g. to detect new patterns in the stock market).
# - Good for limited computing resources (mobile device)
# - Train models on huge datasets that cannot fit in one machine's main memory (out-of-core learning)

# %% [markdown]
# ### 10. What is out-of-core learning?

# %% [markdown]
# The algorithm _loads_ the part of the data, _runs_ a training step on that data, and _repeats_ the process until it has run on all of the data.
#
# ![image.png](attachment:12f09b95-e7c7-4704-a436-fac89947ac90.png)

# %% [markdown]
# ### 11. What type of algorithm relies on a similarity measure to make predictions?

# %% [markdown]
# - **Instance-based** learning uses similarity measures to measure between two emails to count the _number of words_ they have in _common_.

# %% [markdown]
# ### 12. What is the difference between a model parameter and a model hyperparameter?

# %% [markdown]
# 13. What do model-based algorithms search for? What is the most common strategy they use to succeed? How do they make predictions?

# %% [markdown]
# ### 14. Can you name four of the main challenges in machine learning?

# %% [markdown]
# - Insufficient Quantity of Training Data
# - Nonrepresentative Training Data
# - Poor Quality Data
# - Irrelevant Features

# %% [markdown]
# ### 15. If your model performs great on the training data but generalizes poorly to new instances, what is happening? Can you name three possible solutions?

# %% [markdown]
# This happening is called "overfitting". To avoid this, here are the 3 possible solutions:
#
# - Simplify the model by selecting one with fewer parameters, by reducing the number of attributes in the training data, or by constraining the model.
# - Gather more training data.
# - Reduce the noise in the training data (fix data errors and remove outliers)

# %% [markdown]
# ### 16. What is a test set, and why would you want to use it?

# %% [markdown]
# A test set is a set of data that will be used in testing. We would want to use it because we can measure how well our model will perform on instance it has never seen before.

# %% [markdown]
# ### 17. What is the purpose of a validation set?

# %% [markdown]
# The purpose of the a validation set is to evaluate several candidate models to select the best one.

# %% [markdown]
# ### 18. What is the train-dev set, when do you need it, and how do you use it?

# %% [markdown]
# A train-dev set is a solution when you train your model and observe that the performance of the model on the validation set is disappointing, we don't know whether this is because the model has to overfit the training set, or whether this is just due to the mismatch between the data.
#
# We need this train-dev set _after_ the model is trained.
#
# How do we use it?
#
# 1. _Evaluate_ the model on the train-dev set.
#
#     A. If the model performs _poorly_ => it must have overfit the training set.
#        a. Solutions => simplify or _regularize_ the model, get _more_ training data, and _clean_ up the data. \n\n\
#
#    \n\
#
#     B. If the model performs _well_ on the train-dev set, then _evaluate_ the model on the dev set.
#        a. If the model performs _poorly_ on dev set => _problem_ must be coming from the _data mismatch_
#            1. Solutions: Preprocess the data to match other data and retrain the model.
#
# 3. After the model performs well on both the _train-dev_ set and _dev set_, _evaluate_ it one last time on the _test set_ to know how well it is likely to perfrom in production.

# %% [markdown]
# ### 19. What can go wrong if you tune hyperparameters using the test set?

# %% [markdown]
# If you tune hyperparameters using the test set, you risk _overfitting_ the test set, and the generalization error you measure will be optimistic (you may launch a model that performs worse than you expect).

# %% [markdown]
# Solutions to these exercises are available at the end of this chapter’s
# notebook, at https://homl.info/colab3.
